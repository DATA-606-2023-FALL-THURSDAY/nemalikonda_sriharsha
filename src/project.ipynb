# %% [markdown]
# # Analysis of Real Estate Sales Data

# %%
# Import required libraries
import pandas as pd
import plotly.graph_objs as go

# %%
# Read csv file
data =  pd.read_csv('../data/Real_Estate_Sales_2001-2020_GL.csv')
# Out:
# /var/folders/nm/1d_f2pyj48v6g0n27bzllyhc0000gn/T/ipykernel_15422/3218703825.py:2: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data =  pd.read_csv('../data/Real_Estate_Sales_2001-2020_GL.csv')

# %% [markdown]
# *The csv file needs to be in the '/data' folder to match the project path*

# %%
# Display the first 5 elements of the dataframe
data.head()
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    09/13/2021  Ansonia        230 WAKELEE AVE
# 1          20002       2020    10/02/2020  Ashford        390 TURNPIKE RD
# 2         200212       2020    03/09/2021     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020    07/02/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        150500.0     325000.0       0.4630    Commercial              NaN
# 1        253000.0     430000.0       0.5883   Residential    Single Family
# 2        130400.0     179900.0       0.7248   Residential            Condo
# 3        619290.0     890000.0       0.6958   Residential    Single Family
# 4        862330.0    1447500.0       0.5957   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks Location
# 0          NaN              NaN         NaN      NaN
# 1          NaN              NaN         NaN      NaN
# 2          NaN              NaN         NaN      NaN
# 3          NaN              NaN         NaN      NaN
# 4          NaN              NaN         NaN      NaN

# %%
# Display the columns
data.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Non Use Code', 'Assessor Remarks', 'OPM remarks',
#        'Location'],
#       dtype='object')

# %%
# Display the data frame info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461616 entries, 0 to 461615
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     461616 non-null  int64
#  1   List Year         461616 non-null  int64
#  2   Date Recorded     461614 non-null  object
#  3   Town              461616 non-null  object
#  4   Address           461568 non-null  object
#  5   Assessed Value    461616 non-null  float64
#  6   Sale Amount       461616 non-null  float64
#  7   Sales Ratio       461616 non-null  float64
#  8   Property Type     124390 non-null  object
#  9   Residential Type  118526 non-null  object
#  10  Non Use Code      106698 non-null  object
#  11  Assessor Remarks  17058 non-null   object
#  12  OPM remarks       1989 non-null    object
#  13  Location          105602 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 49.3+ MB

# %%
# Generate descriptive statistics.
data.describe()
# Out:
#        Serial Number      List Year  Assessed Value   Sale Amount  \
# count   4.616160e+05  461616.000000    4.616160e+05  4.616160e+05
# mean    5.100584e+05    2005.995043    2.278729e+05  3.873860e+05
# std     8.402169e+06       5.991394    1.172594e+06  7.494047e+06
# min     0.000000e+00    2001.000000    0.000000e+00  0.000000e+00
# 25%     2.075200e+04    2002.000000    7.012000e+04  1.440000e+05
# 50%     4.031500e+04    2004.000000    1.108000e+05  2.300000e+05
# 75%     6.004200e+04    2006.000000    1.879500e+05  3.700000e+05
# max     2.000500e+09    2020.000000    1.229354e+08  5.000000e+09
#
#         Sales Ratio
# count  4.616160e+05
# mean   1.926852e+01
# std    2.746864e+03
# min    0.000000e+00
# 25%    4.102000e-01
# 50%    5.021000e-01
# 75%    6.057172e-01
# max    1.226420e+06

# %% [markdown]
# ### Find the unique elements of the column

# %%
# Create a new DataFrame to store unique values, data type, definition, and potential values
unique_info_df = pd.DataFrame(columns=['Column Name', 'Data Type', 'Definition', 'Potential Values'])

# Loop through each column in the DataFrame
for column in data.columns:
    data_type = data[column].dtype
    definition = ''
    potential_values = data[column].unique()[:5]

    # Append the information to the new DataFrame
    unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
                                            'Definition': definition, 'Potential Values': potential_values},
                                           ignore_index=True)

# Print the unique data in each column
unique_info_df
# Out:
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
# <ipython-input-7-1b5fc37bb21e>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_info_df = unique_info_df.append({'Column Name': column, 'Data Type': data_type,
#          Column Name Data Type Definition  \
# 0      Serial Number     int64
# 1          List Year     int64
# 2      Date Recorded    object
# 3               Town    object
# 4            Address    object
# 5     Assessed Value   float64
# 6        Sale Amount   float64
# 7        Sales Ratio   float64
# 8      Property Type    object
# 9   Residential Type    object
# 10      Non Use Code    object
# 11  Assessor Remarks    object
# 12       OPM remarks    object
# 13          Location    object
#
#                                      Potential Values
# 0            [2020348, 20002, 200212, 200243, 200377]
# 1                      [2020, 2001, 2002, 2003, 2004]
# 2   [09/13/2021, 10/02/2020, 03/09/2021, 04/13/202...
# 3           [Ansonia, Ashford, Avon, Berlin, Bethany]
# 4   [230 WAKELEE AVE, 390 TURNPIKE RD, 5 CHESTNUT ...
# 5   [150500.0, 253000.0, 130400.0, 619290.0, 86233...
# 6   [325000.0, 430000.0, 179900.0, 890000.0, 14475...
# 7             [0.463, 0.5883, 0.7248, 0.6958, 0.5957]
# 8   [Commercial, Residential, Vacant Land, nan, Ap...
# 9   [nan, Single Family, Condo, Two Family, Three ...
# 10  [nan, 08 - Part Interest, 14 - Foreclosure, 25...
# 11  [nan, WATERFRONT/COTTAGE ONLY/LAND IS ASSOCIAT...
# 12  [nan, GAS STATION, GOOD SALE PER MLS, RENOVATE...
# 13  [nan, POINT (-73.18197 41.64672), POINT (-72.2...

# %%
# print(unique_info_df.to_string(index=False))

# %% [markdown]
# ### Number of Properties by Type

# %%
property_counts = data['Property Type'].value_counts().reset_index()
property_counts.columns = ['Property Type', 'Count']

trace = go.Bar(
    x=property_counts['Property Type'],
    y=property_counts['Count']
)

layout = go.Layout(
    title="Number of Properties by Type",
    xaxis=dict(title="Property Type"),
    yaxis=dict(title="Count"),
)

fig = go.Figure(data=[trace], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ea556019-436d-49a7-ba4d-9a8fb7f2bb01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea556019-436d-49a7-ba4d-9a8fb7f2bb01")) {                    Plotly.newPlot(                        "ea556019-436d-49a7-ba4d-9a8fb7f2bb01",                        [{"x":["Residential","Single Family","Condo","Vacant Land","Two Family","Commercial","Three Family","Apartments","Industrial","Four Family","Public Utility","Single Fam"],"y":[60728,40401,13005,3163,2872,1981,1359,486,228,161,5,1],"type":"bar"}],                        {"title":{"text":"Number of Properties by Type"},"xaxis":{"title":{"text":"Property Type"}},"yaxis":{"title":{"text":"Count"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %% [markdown]
# * Large number of properties are of Residential type.

# %% [markdown]
# ### Distribution of Residential Types

# %%
residential_counts = data['Residential Type'].value_counts().reset_index()
residential_counts.columns = ['Residential Type', 'Count']

trace = go.Pie(
    labels=residential_counts['Residential Type'],
    values=residential_counts['Count'],
)

layout = go.Layout(title="Distribution of Residential Types")

fig = go.Figure(data=[trace], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="274b5822-408a-4faf-bcb0-a0e1158059f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("274b5822-408a-4faf-bcb0-a0e1158059f6")) {                    Plotly.newPlot(                        "274b5822-408a-4faf-bcb0-a0e1158059f6",                        [{"labels":["Single Family","Condo","Two Family","Three Family","Four Family"],"values":[83805,25365,6073,2854,429],"type":"pie"}],                        {"title":{"text":"Distribution of Residential Types"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"h ...

# %% [markdown]
# * Large share of the residential types are owned by four family.

# %% [markdown]
# ### Total Sales Amount Over Years

# %%
data['Date Recorded'] = pd.to_datetime(data['Date Recorded'])
data['Year'] = data['Date Recorded'].dt.year
sales_over_years = data.groupby('Year')['Sale Amount'].sum().reset_index()

trace = go.Scatter(
    x=sales_over_years['Year'],
    y=sales_over_years['Sale Amount'],
    mode='lines+markers',
)

layout = go.Layout(
    title="Total Sales Amount Over Years",
    xaxis=dict(title="Year"),
    yaxis=dict(title="Total Sales Amount"),
)

fig = go.Figure(data=[trace], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4c1b9a30-51c6-44e7-83db-dc74f54a07a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c1b9a30-51c6-44e7-83db-dc74f54a07a3")) {                    Plotly.newPlot(                        "4c1b9a30-51c6-44e7-83db-dc74f54a07a3",                        [{"mode":"lines+markers","x":[2001.0,2002.0,2003.0,2004.0,2005.0,2006.0,2007.0,2008.0,2009.0,2010.0,2011.0,2012.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0],"y":[3177170466.0,15603574587.0,17204337985.0,25160810407.0,30213064103.0,21598216379.0,19837833179.4,5058354773.0,40264611.0,54236355.0,23337070.0,45079458.0,30219359.0,68305886.0,67958636.0,39698560.0,38192196.0,73913405.0,94778034.0,8614671501.38,31779543926.64],"type":"scatter"}],                        {"title":{"text":"Total Sales Amount Over Years"},"xaxis":{"title":{"text":"Year"}},"yaxis":{"title":{"text":"Total Sales Amount"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color ...

# %% [markdown]
# * Total sales in 2021 highest among all years.
